# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # importing dataset

# %%
dataset=pd.read_csv("auto-mpg.csv")
dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
dataset.shape
# Out:
# (398, 9)

# %%
dataset.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
dataset.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# # data visualization

# %% [markdown]
# # checking correlation

# %%
dataset.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
# origin        0.563450  -0.562543     -0.609409   -0.455171 -0.581024
#
#               acceleration  model year    origin
# mpg               0.420289    0.579267  0.563450
# cylinders        -0.505419   -0.348746 -0.562543
# displacement     -0.543684   -0.370164 -0.609409
# horsepower       -0.689196   -0.416361 -0.455171
# weight           -0.417457   -0.306564 -0.581024
# ...

# %%
import seaborn as sns
sns.heatmap(dataset.corr())

# %%
sns.pairplot(dataset,diag_kind='kde')
plt.show()

# %%
dataset.hist(bins=20,figsize=(10,10))
plt.show()

# %%
sns.distplot(dataset['mpg']) # plot distribution plot to view the distribution of target variable

# %%
plt.scatter(x=dataset['horsepower'],y=dataset['mpg'])

# %%
plt.scatter(x=dataset['cylinders'],y=dataset['mpg'])

# %%
plt.scatter(x=dataset['displacement'],y=dataset['mpg'])

# %%
plt.scatter(x=dataset['acceleration'],y=dataset['mpg'])

# %%
plt.scatter(x=dataset['weight'],y=dataset['mpg'])

# %%
plt.scatter(x=dataset['model year'],y=dataset['mpg'])

# %% [markdown]
# # filling missing values

# %%
dataset['horsepower'].fillna(dataset['horsepower'].mean(),inplace=True)
dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
dataset['horsepower'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # label encoding

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
dataset.iloc[:,-1]=lb.fit_transform(dataset.iloc[:,-1])
dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin  car name
# 0            70       1        49
# 1            70       1        36
# ...

# %% [markdown]
# # removing outliers

# %%
from scipy import stats
z=np.abs(stats.zscore(dataset))
z
# Out:
# array([[0.7064387 , 1.49819126, 1.0906037 , ..., 1.62742629, 0.71514478,
#         1.11374457],
#        [1.09075062, 1.49819126, 1.5035143 , ..., 1.62742629, 0.71514478,
#         1.25918548],
#        [0.7064387 , 1.49819126, 1.19623199, ..., 1.62742629, 0.71514478,
#         0.92242821],
#        ...,
#        [1.08701694, 0.85632057, 0.56103873, ..., 1.62198339, 0.71514478,
#         0.33060119],
#        [0.57460104, 0.85632057, 0.70507731, ..., 1.62198339, 0.71514478,
#         0.11690931],
#        [0.95891297, 0.85632057, 0.71467988, ..., 1.62198339, 0.71514478,
#         0.88998932]])

# %%
np.where(z>3)
# Out:
# (array([  6,   8,  13,  95, 116, 299, 394], dtype=int64),
#  array([3, 3, 3, 3, 3, 5, 5], dtype=int64))

# %%
dataset_no_outliers=dataset[(z<=3).all(axis=1)]
dataset_no_outliers
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin  car name
# 0            70       1        49
# 1            70       1        36
# ...

# %%
dataset=dataset_no_outliers
dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin  car name
# 0            70       1        49
# 1            70       1        36
# ...

# %%
dataset.drop(dataset.columns[[-1]],axis=1,inplace=True)
dataset
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# ...

# %% [markdown]
# # seperating independent and dependent variables

# %%
x=dataset.iloc[:,1:].values
x
# Out:
# array([[  8. , 307. , 130. , ...,  12. ,  70. ,   1. ],
#        [  8. , 350. , 165. , ...,  11.5,  70. ,   1. ],
#        [  8. , 318. , 150. , ...,  11. ,  70. ,   1. ],
#        ...,
#        [  4. , 135. ,  84. , ...,  11.6,  82. ,   1. ],
#        [  4. , 120. ,  79. , ...,  18.6,  82. ,   1. ],
#        [  4. , 119. ,  82. , ...,  19.4,  82. ,   1. ]])

# %%
y=dataset.iloc[:,0].values
y
# Out:
# array([18. , 15. , 18. , 16. , 17. , 15. , 14. , 15. , 15. , 14. , 15. ,
#        24. , 22. , 18. , 21. , 27. , 26. , 25. , 24. , 25. , 26. , 21. ,
#        10. , 10. , 11. ,  9. , 27. , 28. , 25. , 25. , 19. , 16. , 17. ,
#        19. , 18. , 14. , 14. , 14. , 14. , 12. , 13. , 13. , 18. , 22. ,
#        19. , 18. , 23. , 28. , 30. , 30. , 31. , 35. , 27. , 26. , 24. ,
#        25. , 23. , 20. , 21. , 13. , 14. , 15. , 14. , 17. , 11. , 13. ,
#        12. , 13. , 19. , 15. , 13. , 13. , 14. , 18. , 22. , 21. , 26. ,
#        22. , 28. , 23. , 28. , 27. , 13. , 14. , 13. , 14. , 15. , 12. ,
#        13. , 13. , 14. , 13. , 13. , 18. , 16. , 18. , 18. , 23. , 26. ,
#        11. , 12. , 13. , 12. , 18. , 20. , 21. , 22. , 18. , 19. , 21. ,
#        26. , 15. , 29. , 24. , 20. , 19. , 15. , 24. , 20. , 11. , 20. ,
#        21. , 19. , 15. , 31. , 26. , 32. , 25. , 16. , 16. , 18. , 16. ,
#        13. , 14. , 14. , 14. , 29. , 26. , 26. , 31. , 32. , 28. , 24. ,
# ...

# %%
x.shape
# Out:
# (391, 7)

# %% [markdown]
# # one hot encoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct=ColumnTransformer([("on",OneHotEncoder(),[6])],remainder="passthrough")
x=ct.fit_transform(x)
x
# Out:
# array([[1.000e+00, 0.000e+00, 0.000e+00, ..., 3.504e+03, 1.200e+01,
#         7.000e+01],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 3.693e+03, 1.150e+01,
#         7.000e+01],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 3.436e+03, 1.100e+01,
#         7.000e+01],
#        ...,
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 2.295e+03, 1.160e+01,
#         8.200e+01],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 2.625e+03, 1.860e+01,
#         8.200e+01],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 2.720e+03, 1.940e+01,
#         8.200e+01]])

# %% [markdown]
# # removing dummy variable

# %%
x=x[:,1:]
x
# Out:
# array([[   0. ,    0. ,    8. , ..., 3504. ,   12. ,   70. ],
#        [   0. ,    0. ,    8. , ..., 3693. ,   11.5,   70. ],
#        [   0. ,    0. ,    8. , ..., 3436. ,   11. ,   70. ],
#        ...,
#        [   0. ,    0. ,    4. , ..., 2295. ,   11.6,   82. ],
#        [   0. ,    0. ,    4. , ..., 2625. ,   18.6,   82. ],
#        [   0. ,    0. ,    4. , ..., 2720. ,   19.4,   82. ]])

# %%
x.shape
# Out:
# (391, 8)

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.45883147, -0.50319492,  1.52426772, ...,  0.65433722,
#         -1.37036472, -1.64972638],
#        [-0.45883147, -0.50319492,  1.52426772, ...,  0.88003194,
#         -1.56101823, -1.64972638],
#        [-0.45883147, -0.50319492,  1.52426772, ...,  0.57313489,
#         -1.75167173, -1.64972638],
#        ...,
#        [-0.45883147, -0.50319492, -0.84782652, ..., -0.78939245,
#         -1.52288753,  1.62321915],
#        [-0.45883147, -0.50319492, -0.84782652, ..., -0.39532231,
#          1.14626153,  1.62321915],
#        [-0.45883147, -0.50319492, -0.84782652, ..., -0.28187788,
#          1.45130713,  1.62321915]])

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[ 2.17944947, -0.50319492, -0.84782652, ..., -0.83835267,
#          3.01466587, -1.10423546],
#        [-0.45883147, -0.50319492,  1.52426772, ...,  0.72479219,
#         -2.13297874, -1.64972638],
#        [-0.45883147, -0.50319492, -0.84782652, ..., -0.86701232,
#         -0.41709721,  0.5322373 ],
#        ...,
#        [ 2.17944947, -0.50319492, -0.84782652, ..., -0.353527  ,
#         -0.60775071, -0.83149   ],
#        [ 2.17944947, -0.50319492, -0.84782652, ..., -0.99478658,
#         -0.60775071, -1.37698092],
#        [ 2.17944947, -0.50319492, -0.84782652, ..., -0.31292583,
#         -0.2264437 , -0.28599908]])

# %%
x_test
# Out:
# array([[-0.45883147,  1.98730146, -0.84782652, -0.768685  , -0.22738359,
#         -0.80969303, -0.0357902 , -1.10423546],
#        [-0.45883147,  1.98730146, -0.84782652, -1.10545889, -1.00878319,
#         -1.20137486,  1.29878433, -0.55874454],
#        [-0.45883147,  1.98730146, -0.84782652, -0.81821058, -0.78552616,
#         -0.72371409,  0.45990891,  1.35047369],
#        [ 2.17944947, -0.50319492, -0.84782652, -0.68944409,  0.33075897,
#         -0.34039132, -0.79840421, -0.28599908],
#        [-0.45883147, -0.50319492,  1.52426772,  1.57882709,  1.44704411,
#          1.67653127, -0.2645744 ,  0.80498276],
#        [ 2.17944947, -0.50319492, -0.84782652, -1.10545889, -1.25994734,
#         -1.35064385,  1.14626153,  0.25949184],
#        [-0.45883147,  1.98730146, -0.84782652, -1.03612309, -1.06459745,
#         -1.11897838,  0.30738611,  1.07772823],
#        [-0.45883147, -0.50319492,  1.52426772,  1.26186343,  0.88890154,
#          1.04363075, -0.1501823 ,  0.80498276],
# ...

# %%
y_train
# Out:
# array([23. , 15. , 30.9, 14. , 31. , 21.5, 34.3, 24.5, 17. , 30.5, 31.6,
#        19.8, 27. , 32.3, 36.1, 27. , 13. , 25. , 21. , 33.5, 27. , 28. ,
#        30. , 17. , 30.7, 13. , 36. , 17. , 30. , 26. , 32.9, 10. , 25.5,
#        24. , 41.5, 17. , 18. , 25. , 12. , 15. , 16. , 22. , 13. , 38.1,
#        31.8, 40.8, 29.5, 25. , 19. , 15. , 31. , 19. , 20. , 32. , 18. ,
#        19. , 16. , 23. , 15. , 30. , 20. , 29. , 20.6, 28.8, 29. , 23.9,
#        32. , 28. , 34.5, 29.5, 14. , 19. , 36. , 18. , 21.5, 23. , 14. ,
#        38. , 24.2, 18.5, 26. , 38. , 24.5, 19. , 23. , 31.3, 33. , 30. ,
#        18. , 26. , 38. , 29. , 27. , 25. , 17.6, 35. , 43.4, 34.1, 28. ,
#        18. , 32. , 16. , 20.2, 24. , 34.4, 26. , 33.5, 23. , 40.9, 21.6,
#        15.5, 14. , 18.1, 25.8, 11. , 17.5, 19. , 17.5, 16. , 18. , 15. ,
#        24. , 20.2, 29. , 19.4, 24. , 25. , 23. , 29. , 26. , 13. , 20.8,
#        23.6, 34. , 20.5, 20. , 20. , 13. , 14. , 22.5, 32. , 20. , 33.5,
# ...

# %%
y_test
# Out:
# array([24. , 31. , 32.4, 25. , 16.9, 36. , 37.2, 18.2, 12. , 18.5, 24. ,
#        14. , 19. , 26.4, 19.2, 13. , 19. , 24. , 18.6, 27. , 32.7, 19.4,
#        32.2, 26. , 25.4, 21. , 37.3, 29. , 25.5, 17.5, 18.5, 33.8, 37. ,
#        22. , 14. , 15. , 35.1, 27.9, 30.5, 31. , 12. , 14. , 16.5, 15. ,
#        27. , 18. , 13. , 28. , 19.2, 22. , 35. , 27. , 16.5, 20.2, 15. ,
#        22. , 24. , 15. , 30. , 23.7, 13. , 15.5, 43.1, 27.2, 26. , 33.7,
#        32.8, 27.2, 28. , 14. , 20. , 11. , 25. , 14. , 13. , 22. , 20.5,
#        25.1, 34.1])

# %%
x_train.shape
# Out:
# (312, 8)

# %%
x_test.shape
# Out:
# (79, 8)

# %%
y_train.shape
# Out:
# (312,)

# %%
y_test.shape
# Out:
# (79,)

# %% [markdown]
# # evaluation

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=100,criterion="mae",random_state=0)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mae',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
y_pred=rf.predict(x_test)
y_pred
# Out:
# array([24.429 , 31.3   , 33.375 , 22.439 , 16.108 , 30.331 , 40.016 ,
#        16.611 , 12.52  , 17.755 , 28.28  , 13.67  , 18.744 , 24.605 ,
#        19.595 , 13.585 , 23.03  , 23.589 , 19.23  , 28.012 , 22.305 ,
#        16.931 , 34.337 , 27.454 , 24.483 , 18.973 , 35.105 , 27.755 ,
#        25.193 , 15.297 , 16.006 , 36.1395, 37.348 , 27.067 , 11.715 ,
#        14.06  , 38.392 , 24.659 , 30.242 , 28.24  , 12.81  , 13.19  ,
#        17.09  , 13.806 , 26.78  , 19.199 , 12.895 , 28.545 , 20.165 ,
#        19.565 , 31.727 , 26.79  , 17.975 , 21.122 , 11.745 , 23.448 ,
#        23.676 , 12.07  , 31.441 , 34.958 , 14.08  , 15.793 , 35.626 ,
#        29.41  , 22.872 , 34.941 , 35.678 , 25.622 , 24.61  , 14.825 ,
#        19.069 , 12.46  , 27.885 , 14.32  , 14.989 , 24.634 , 19.899 ,
#        25.058 , 36.329 ])

# %%
y_test
# Out:
# array([24. , 31. , 32.4, 25. , 16.9, 36. , 37.2, 18.2, 12. , 18.5, 24. ,
#        14. , 19. , 26.4, 19.2, 13. , 19. , 24. , 18.6, 27. , 32.7, 19.4,
#        32.2, 26. , 25.4, 21. , 37.3, 29. , 25.5, 17.5, 18.5, 33.8, 37. ,
#        22. , 14. , 15. , 35.1, 27.9, 30.5, 31. , 12. , 14. , 16.5, 15. ,
#        27. , 18. , 13. , 28. , 19.2, 22. , 35. , 27. , 16.5, 20.2, 15. ,
#        22. , 24. , 15. , 30. , 23.7, 13. , 15.5, 43.1, 27.2, 26. , 33.7,
#        32.8, 27.2, 28. , 14. , 20. , 11. , 25. , 14. , 13. , 22. , 20.5,
#        25.1, 34.1])

# %% [markdown]
# # checking accuracy

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8671755093027755
